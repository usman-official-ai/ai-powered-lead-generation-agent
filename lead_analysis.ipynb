# %% [markdown]
# # Lead Analysis - Task 5\nLoading the dataset using Pandas

# %%
import pandas as pd
print('Pandas imported successfully')

# %% [markdown]
# ## Task 1: Read CSV

# %%
df = pd.read_excel('business_leads_50_complete.xlsx')
print('Dataset loaded successfully!')

# %% [markdown]
# ## Task 2: Display first 5 rows

# %%
df.head()

# %% [markdown]
# ## Task 3: Count companies by country

# %%
print('Count by Country:')
print(df['Country'].value_counts())

# %% [markdown]
# ## Task 4: Count companies by industry

# %%
print('Count by Industry:')
print(df['Industry'].value_counts())

# %% [markdown]
# ## Save as CSV for future use

# %%
df.to_csv('leads_dataset.csv', index=False)
print('Saved as leads_dataset.csv')
